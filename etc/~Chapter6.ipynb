# %%
import tensorflow as tf
box = tf.constant("Hello World")
tf.print(box) #2.0.0 부터 Session 함수 삭제
# Out:
# Hello World

# %%
import pandas as pd
pd.read_csv('C:/01.project/01.분석참조모델/민원분석/03.R분석파일/Data/새올/새올민원자료(샘플).csv', encoding='cp949').head()
# Out:
#                 민원접수번호      민원등록일자            민원등록일시  \
# 0  '201601010019445046  2016-01-01   2016-01-01 0:25
# 1  '201601010021535047  2016-01-01   2016-01-01 0:28
# 2  '201601010022585048  2016-01-01   2016-01-01 0:29
# 3  '201601010024225049  2016-01-01   2016-01-01 0:30
# 4  '201601011148125050  2016-01-01  2016-01-01 11:54
#
#                                           민원제목  \
# 0  [생활불편스마트폰신고]장애인 전용주차 구역 불법주차[G000001131486]
# 1  [생활불편스마트폰신고]장애인 전용주차 구역 불법주차[G000001131487]
# 2  [생활불편스마트폰신고]장애인 전용주차 구역 불법주차[G000001131488]
# 3  [생활불편스마트폰신고]장애인 전용주차 구역 불법주차[G000001131489]
# 4  [생활불편스마트폰신고]장애인 전용주차 구역 불법주차[G000001131825]
#
#                                                 민원내용            처리기한일시  \
# 0  불법 주정차 신고  불법주차[ 상세위치설명 : 삼계동  푸르지오1차 ]\r\n경상남...  2016-01-09 18:00
# 1  불법 주정차 신고  장애전용불법주차[ 상세위치설명 : 푸르지오1차 ]\r\n경상남도...  2016-01-09 18:00
# 2  불법 주정차 신고  불법주차[ 상세위치설명 : 푸르지오1차 ]\r\n경상남도 김해시...  2016-01-09 18:00
# ...

# %%
names=['a', 'b', 'c']
a = pd.read_csv('법정동별현황 데이터.csv', names=names, encoding='cp949', header=None)

print(a)
# Out:
#         a     b       c
# 0    행정동명  법정동명    총인구수
# 1     진영읍   진영읍   46845
# 2     주촌면   주촌면    3358
# 3     진례면   진례면    7776
# 4     한림면   한림면    8837
# 5     생림면   생림면    4227
# 6     상동면   상동면    3566
# 7     대동면   대동면    7166
# 8     동상동   동상동     NaN
# 9     회현동   서상동    1751
# 10    회현동   봉황동    6683
# 11    부원동   부원동   10315
# 12    내외동    내동   33014
# 13    내외동    외동   50371
# 14    북부동   대성동    5076
# 15    북부동   구산동   32246
# 16    북부동   삼계동   47959
# 17  칠산서부동    흥동    3686
# 18  칠산서부동   풍유동    1118
# 19  칠산서부동   명법동     292
# 20  칠산서부동    이동     542
# 21  칠산서부동   화목동    1406
# 22  칠산서부동   전하동    2887
# 23  칠산서부동    강동     283
# 24    활천동   삼정동   19895
# 25    활천동   어방동   25918
# 26    삼안동   삼방동   32568
# 27    삼안동    안동    7292
# 28    불암동   지내동    7463
# 29    불암동   불암동    1095
# 30    장유동   장유면  144931

# %%
import csv
with open('주소매핑현황.csv', encoding='cp949') as f:
    lines = list(csv.reader(f))

# %%
header, values = lines[0], lines[1:]

# %%
data_dict = {h: v for h, v in zip(header, zip(*values))}
print(data_dict)
# Out:
# {'법정동.주소': ('', '"', '0', '1', '2', '3', 'Avenue', 'b""', 'blv""', 'Court', 'Cresent""', 'Ct""', 'Curraheen""', 'dei', 'Dorstone', 'Drive', 'Drive""', 'Followthru', 'Hwy""', 'Mingou', 'Munich', 'Munich""', 'OerErkenschwick""', 'Road', 'Road""', 'Square', 'Str""', 'Street""', 'Trail', 'W""', '가남읍', '가능동', '가락동', '가북면', '가산동', '가수동', '가정동', '가조면', '가좌동', '가학동', '갈산동', '감곡면', '감삼동', '강서동', '개봉동', '개포동', '건천읍', '경서동', '계수동', '고강동', '고창읍', '공덕면', '공릉동', '공촌동', '과천동', '광명동', '광양읍', '괴안동', '구래동', '구로동', '구림면', '구월동', '구의동', '구좌읍', '권선구', '금산면', '금서면', '금호동가', '금호읍', '기흥구', '낙성대동', '난곡동', '난향동', '남교동', '남구', '남상면', '남양읍', '남현동', '내곡동', '내산면', '내손동', '내용없음', '노원동가', '노형동', '논현동', '다대동', '다산집현면', '단성면', '단원구', '답십리동', '당정동', '대덕면', '대림동', '대명동', '대방동', '대야미동', '대치동', '대학동', '대흥동', '덕양구', '덕풍동', '도곡동', '도림동', '도천면', '도화동', '독산동', '동남구', '동량면', '동안구', '동자동', '랜드마크로', '마곡동', '마산합포구', '마전동', '마포동', '만수동', '만안구', '목동', '문래동가', '문산읍', '문정동', '미성동', '미아동', '미평동', '반구동', '반석동""', '반송동', '반포동', '방배동', 
# ...

# %%
import csv
f = open('법정동별현황 데이터.csv', encoding='cp949')

reader = csv.reader(f, delimiter='|')

for line in reader:
    print(line)
    
f.close()
# Out:
# ['행정동명,법정동명,총인구수']
# ['진영읍,진영읍,46845']
# ['주촌면,주촌면,3358']
# ['진례면,진례면,7776']
# ['한림면,한림면,8837']
# ['생림면,생림면,4227']
# ['상동면,상동면,3566']
# ['대동면,대동면,7166']
# ['동상동,동상동,']
# ['회현동,서상동,1751']
# ['회현동,봉황동,6683']
# ['부원동,부원동,10315']
# ['내외동,내동,33014']
# ['내외동,외동,50371']
# ['북부동,대성동,5076']
# ['북부동,구산동,32246']
# ['북부동,삼계동,47959']
# ['칠산서부동,흥동,3686']
# ['칠산서부동,풍유동,1118']
# ['칠산서부동,명법동,292']
# ['칠산서부동,이동,542']
# ['칠산서부동,화목동,1406']
# ['칠산서부동,전하동,2887']
# ['칠산서부동,강동,283']
# ['활천동,삼정동,19895']
# ['활천동,어방동,25918']
# ['삼안동,삼방동,32568']
# ['삼안동,안동,7292']
# ['불암동,지내동,7463']
# ['불암동,불암동,1095']
# ['장유동,장유면,144931']

# %%
with open('mydata.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(('one', 'two', 'three'))
    writer.writerow(('1', '2', '3'))
    writer.writerow(('4', '5', '6'))
    writer.writerow(('7', '8', '9'))

# %%
import pandas as pd

tables = pd.read_html('examples/fdic_failed_bank_list.html')

# print(len(tables))

failures = tables[0]
failures.head()
# Out:
# 1
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# 2  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016
# 3           The Bank of Fayette County      April 29, 2016  September 6, 2016
# 4  First-Citizens Bank & Trust Company      March 11, 2016      June 16, 2016

# %%
close_timestamps = pd.to_datetime(failures['Closing Date'])
close_timestamps.dt.year.value_counts()
# Out:
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2015      8
# 2016      5
# 2004      4
# 2001      4
# 2007      3
# 2003      3
# 2000      2
# Name: Closing Date, dtype: int64

# %%
from lxml import objectify

path = 'datasets/mta_perf/Performance_MNR.xml'
parsed = objectify.parse(open(path))
root = parsed.getroot()

data = []
skip_fields = ['PARENT_SEQ', 'INDICATOR_SEQ', 'DESIRED_CHANGE','DECIMAL_PLACES']

for elt in root.INDICATOR:
    el_data={}
    for child in elt.getchildren():
        if child.tag in skip_fields:
            continue
        el_data[child.tag] = child.pyval
    data.append(el_data)

# %%
perf = pd.DataFrame(data)
perf.head()
# Out:
#             AGENCY_NAME                        INDICATOR_NAME  \
# 0  Metro-North Railroad  On-Time Performance (West of Hudson)
# 1  Metro-North Railroad  On-Time Performance (West of Hudson)
# 2  Metro-North Railroad  On-Time Performance (West of Hudson)
# 3  Metro-North Railroad  On-Time Performance (West of Hudson)
# 4  Metro-North Railroad  On-Time Performance (West of Hudson)
#
#                                          DESCRIPTION  PERIOD_YEAR  \
# 0  Percent of commuter trains that arrive at thei...         2008
# 1  Percent of commuter trains that arrive at thei...         2008
# 2  Percent of commuter trains that arrive at thei...         2008
# 3  Percent of commuter trains that arrive at thei...         2008
# 4  Percent of commuter trains that arrive at thei...         2008
#
#    PERIOD_MONTH            CATEGORY FREQUENCY INDICATOR_UNIT YTD_TARGET  \
# 0             1  Service Indicators         M              %         95
# ...

# %%
from io import StringIO
tag = '<a href="http://www.google.com">Google</a>'
root = objectify.parse(StringIO(tag)).getroot()

root
root.get('href')
root.text
# Out:
# 'Google'

# %%
import pandas as pd
frame = pd.read_csv('examples/ex1.csv')

frame
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
frame.to_pickle('examples/ex1.csv')

# %%
pd.read_pickle('examples/ex1.csv')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data[0]['title']
# Out:
# 'BUG: wrong dateutil dependency link in dependency graph'

# %%
issues = pd.DataFrame(data, columns = ['number', 'title', 'labels', 'state'])
issues
# Out:
#     number                                              title  \
# 0    42199  BUG: wrong dateutil dependency link in depende...
# 1    42198  API: combine casting behavior with extension t...
# 2    42197  PERF: IntervalArray.unique, IntervalIndex.inte...
# 3    42196                                      CI: Pin numpy
# 4    42195  PERF: Try fast/slow paths only once in DataFra...
# 5    42193            DOC: Correct docstring for Series.apply
# 6    42192   DOC: Move Other bugfixes to appropriate sections
# 7    42191               CLN: Combine checknull/checknull_old
# 8    42190                           Fixing the issue GH42101
# 9    42188  BUG: DataFrame index name is missing after cal...
# 10   42187      CLN: simplify Styler copy mechanics and tests
# 11   42186  STYLE: moving spacing conventions in cython ca...
# 12   42185  BUG: pd.cut raises with duplicated index and `...
# 13   42184            CLN: remove redundant _get_unique_index
# ...
